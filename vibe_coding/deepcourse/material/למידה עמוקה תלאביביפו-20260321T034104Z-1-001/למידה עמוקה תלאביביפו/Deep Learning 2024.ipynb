# %%
# Out:
# <center> <img src = "https://drive.google.com/uc?id=1uF9LDeXJNEHwKVLJypygzJ7g3xLwtAtK" width=600 </center>

# %% [markdown]
# <div dir=rtl>
#
# # למידה עמוקה סמסטר א' 2024
# קורס מספר 142192

# %% [markdown]
# <div dir=rtl>
#
# ## אדמיניסטרציה
#
# * [סילבוס הקורס](https://colab.research.google.com/drive/1RB9-XZKaUWJsPt_k-cScQkE1GDlaqSY3?usp=sharing)

# %% [markdown]
# <div dir=rtl>
#
# ## שיעורים

# %% [markdown]
# <div dir=rtl>
#
#
# ### [שיעור ראשון](https://colab.research.google.com/drive/1azW6049VugRNxIrBvzV_rV9gkPlgrxvw?usp=sharing)

# %% [markdown]
# <div dir=rtl>
#
# ## תרגילים
#
# ### [תרגיל ראשון](https://colab.research.google.com/drive/1r_2RnUv8vD5kXZ6ltc0ywlKCYgRsDkQi?usp=sharing)
# מועד הגשה: 1.1.24
