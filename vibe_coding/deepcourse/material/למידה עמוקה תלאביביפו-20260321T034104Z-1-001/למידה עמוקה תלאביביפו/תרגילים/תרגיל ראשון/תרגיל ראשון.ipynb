# %%
from IPython.display import HTML
HTML('<center> <img src=https://drive.google.com/uc?id=1S85D1HJLHv0DBOFV6YEjZ5gArL9xg8Qk width="400"></center>')
# Out:
# <center> <img src=https://drive.google.com/uc?id=1S85D1HJLHv0DBOFV6YEjZ5gArL9xg8Qk width="400"></center>

# %% [markdown]
# <div dir=rtl>
#
# ## תיאור
#
# תרגיל זה לא דורש תכנות, רק שימוש בכלי ווזואליזציה מתמטי.

# %% [markdown]
# <div dir=rtl>
#
# צרו בעזרת  [גאוגברה](https://www.geogebra.org/) דוגמה של קירוב אוסף דוגמאות ע"י בחירה של פונקציות ממשפחה פרמטרית של פונקציות.
#
# בדומה למה שראינו בשיעור, הוויזואליזציה שלכם אמורה לכלול אוסף של נקודות ופונקציה עם פרמטרים שניתן לשלוט בערכם. מי שמשתמש בוויזואליזציה שלכם, אמור לנסות לקרב את הנקודות בעזרת הפונקציה המתאימה ביותר, ממשפחת הפונקציות.
#
# * [הנה דוגמה לפתרון](https://www.geogebra.org/graphing/etbbbjsz)
# * [והנה עוד דוגמה לפתרון](https://www.geogebra.org/calculator/qbrvs4rw)
#
# נסו לחשוב על משפחה מעניינת של פונקציות.
# מספר הפרמטרים של משפחת הפונקציות, תלוי בכם, אבל צריך להיות גדול מ - 1.
# אפשר גם לבחור להראות את ה trace ובכך להמחיש את אופי המשפחה כולה.
# אפשר גם לנסות לבחור משפחה של פונקציות שמקבלות שני משתנים,
# [כמו בדוגמה הזו](https://www.geogebra.org/calculator/d5r7twu7), אבל גאוגברה בתלת ממד, לא לגמרי בשלה, כנראה.
#
# אם מעניין אתכם לדעת קצת יותר על גאוגברה, הכנתי פעם [סרטון הכרות קצר](https://www.youtube.com/watch?v=TJE2RrLs7j4) אבל הגרסה של התוכנה קצת השתנתה מאז.

# %% [markdown]
# <div dir=rtl>
#
# ## הגשה

# %% [markdown]
# <div dir=rtl>
#
# * הגשה של לינק לוויזואליזציה פומבית של גאוגברה, דרך המהמה.
#
# * הגשה בזוגות
